# %% [markdown]
# All the necessary libraries are imported

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import requests

# %% [markdown]
# Data is imported to Dataframe from Wikipedia

# %%
url="https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
table = pd.read_html(url)
df=pd.DataFrame(table[0])
df
# Out:
#     Postcode           Borough  \
# 0        M1A      Not assigned
# 1        M2A      Not assigned
# 2        M3A        North York
# 3        M4A        North York
# 4        M5A  Downtown Toronto
# 5        M5A  Downtown Toronto
# 6        M6A        North York
# 7        M6A        North York
# 8        M7A      Queen's Park
# 9        M8A      Not assigned
# 10       M9A         Etobicoke
# 11       M1B       Scarborough
# 12       M1B       Scarborough
# 13       M2B      Not assigned
# 14       M3B        North York
# 15       M4B         East York
# 16       M4B         East York
# 17       M5B  Downtown Toronto
# 18       M5B  Downtown Toronto
# 19       M6B        North York
# 20       M7B      Not assigned
# 21       M8B      Not assigned
# 22       M9B         Etobicoke
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M1C       Scarborough
# 28       M1C       Scarborough
# 29       M1C       Scarborough
# ..       ...               ...
# 258      M9X      Not assigned
# 259      M1Y      Not assigned
# 260      M2Y      Not assigned
# 261      M3Y      Not assigned
# 262      M4Y  Downtown Toronto
# 263      M5Y      Not assigned
# 264      M6Y      Not assigned
# 265      M7Y      East Toronto
# 266      M8Y         Etobicoke
# 267      M8Y         Etobicoke
# 268      M8Y         Etobicoke
# 269      M8Y         Etobicoke
# 270      M8Y         Etobicoke
# 271      M8Y         Etobicoke
# 272      M8Y         Etobicoke
# 273      M8Y         Etobicoke
# 274      M9Y      Not assigned
# 275      M1Z      Not assigned
# 276      M2Z      Not assigned
# 277      M3Z      Not assigned
# 278      M4Z      Not assigned
# 279      M5Z      Not assigned
# 280      M6Z      Not assigned
# 281      M7Z      Not assigned
# 282      M8Z         Etobicoke
# 283      M8Z         Etobicoke
# 284      M8Z         Etobicoke
# 285      M8Z         Etobicoke
# 286      M8Z         Etobicoke
# 287      M9Z      Not assigned
#
#                                          Neighbourhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                                         Harbourfront
# 5                                          Regent Park
# 6                                     Lawrence Heights
# 7                                       Lawrence Manor
# 8                                         Not assigned
# 9                                         Not assigned
# 10                                    Islington Avenue
# 11                                               Rouge
# 12                                             Malvern
# 13                                        Not assigned
# 14                                     Don Mills North
# 15                                    Woodbine Gardens
# 16                                       Parkview Hill
# 17                                             Ryerson
# 18                                     Garden District
# 19                                           Glencairn
# 20                                        Not assigned
# 21                                        Not assigned
# 22                                          Cloverdale
# 23                                           Islington
# 24                                        Martin Grove
# 25                                    Princess Gardens
# 26                                     West Deane Park
# 27                                      Highland Creek
# 28                                          Rouge Hill
# 29                                          Port Union
# ..                                                 ...
# 258                                       Not assigned
# 259                                       Not assigned
# 260                                       Not assigned
# 261                                       Not assigned
# 262                               Church and Wellesley
# 263                                       Not assigned
# 264                                       Not assigned
# 265  Business Reply Mail Processing Centre 969 Eastern
# 266                                         Humber Bay
# 267                                   King's Mill Park
# 268                           Kingsway Park South East
# 269                                          Mimico NE
# 270                                     Old Mill South
# 271                                 The Queensway East
# 272                              Royal York South East
# 273                                           Sunnylea
# 274                                       Not assigned
# 275                                       Not assigned
# 276                                       Not assigned
# 277                                       Not assigned
# 278                                       Not assigned
# 279                                       Not assigned
# 280                                       Not assigned
# 281                                       Not assigned
# 282                           Kingsway Park South West
# 283                                          Mimico NW
# 284                                 The Queensway West
# 285                              Royal York South West
# 286                                     South of Bloor
# 287                                       Not assigned
#
# [288 rows x 3 columns]

# %% [markdown]
# The dataframe will consist of three columns: PostalCode, Borough, and Neighborhood

# %%
df.columns=['Postcode','Borough','Neighbourhood']
df
# Out:
#     Postcode           Borough  \
# 0        M1A      Not assigned
# 1        M2A      Not assigned
# 2        M3A        North York
# 3        M4A        North York
# 4        M5A  Downtown Toronto
# 5        M5A  Downtown Toronto
# 6        M6A        North York
# 7        M6A        North York
# 8        M7A      Queen's Park
# 9        M8A      Not assigned
# 10       M9A         Etobicoke
# 11       M1B       Scarborough
# 12       M1B       Scarborough
# 13       M2B      Not assigned
# 14       M3B        North York
# 15       M4B         East York
# 16       M4B         East York
# 17       M5B  Downtown Toronto
# 18       M5B  Downtown Toronto
# 19       M6B        North York
# 20       M7B      Not assigned
# 21       M8B      Not assigned
# 22       M9B         Etobicoke
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M1C       Scarborough
# 28       M1C       Scarborough
# 29       M1C       Scarborough
# ..       ...               ...
# 258      M9X      Not assigned
# 259      M1Y      Not assigned
# 260      M2Y      Not assigned
# 261      M3Y      Not assigned
# 262      M4Y  Downtown Toronto
# 263      M5Y      Not assigned
# 264      M6Y      Not assigned
# 265      M7Y      East Toronto
# 266      M8Y         Etobicoke
# 267      M8Y         Etobicoke
# 268      M8Y         Etobicoke
# 269      M8Y         Etobicoke
# 270      M8Y         Etobicoke
# 271      M8Y         Etobicoke
# 272      M8Y         Etobicoke
# 273      M8Y         Etobicoke
# 274      M9Y      Not assigned
# 275      M1Z      Not assigned
# 276      M2Z      Not assigned
# 277      M3Z      Not assigned
# 278      M4Z      Not assigned
# 279      M5Z      Not assigned
# 280      M6Z      Not assigned
# 281      M7Z      Not assigned
# 282      M8Z         Etobicoke
# 283      M8Z         Etobicoke
# 284      M8Z         Etobicoke
# 285      M8Z         Etobicoke
# 286      M8Z         Etobicoke
# 287      M9Z      Not assigned
#
#                                          Neighbourhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                                         Harbourfront
# 5                                          Regent Park
# 6                                     Lawrence Heights
# 7                                       Lawrence Manor
# 8                                         Not assigned
# 9                                         Not assigned
# 10                                    Islington Avenue
# 11                                               Rouge
# 12                                             Malvern
# 13                                        Not assigned
# 14                                     Don Mills North
# 15                                    Woodbine Gardens
# 16                                       Parkview Hill
# 17                                             Ryerson
# 18                                     Garden District
# 19                                           Glencairn
# 20                                        Not assigned
# 21                                        Not assigned
# 22                                          Cloverdale
# 23                                           Islington
# 24                                        Martin Grove
# 25                                    Princess Gardens
# 26                                     West Deane Park
# 27                                      Highland Creek
# 28                                          Rouge Hill
# 29                                          Port Union
# ..                                                 ...
# 258                                       Not assigned
# 259                                       Not assigned
# 260                                       Not assigned
# 261                                       Not assigned
# 262                               Church and Wellesley
# 263                                       Not assigned
# 264                                       Not assigned
# 265  Business Reply Mail Processing Centre 969 Eastern
# 266                                         Humber Bay
# 267                                   King's Mill Park
# 268                           Kingsway Park South East
# 269                                          Mimico NE
# 270                                     Old Mill South
# 271                                 The Queensway East
# 272                              Royal York South East
# 273                                           Sunnylea
# 274                                       Not assigned
# 275                                       Not assigned
# 276                                       Not assigned
# 277                                       Not assigned
# 278                                       Not assigned
# 279                                       Not assigned
# 280                                       Not assigned
# 281                                       Not assigned
# 282                           Kingsway Park South West
# 283                                          Mimico NW
# 284                                 The Queensway West
# 285                              Royal York South West
# 286                                     South of Bloor
# 287                                       Not assigned
#
# [288 rows x 3 columns]

# %% [markdown]
# Cells that have an 'Not assigned' borough will be dropped.

# %%
df.drop(df[df['Borough']=="Not assigned"].index,axis=0, inplace=True)
df
# Out:
#     Postcode           Borough  \
# 2        M3A        North York
# 3        M4A        North York
# 4        M5A  Downtown Toronto
# 5        M5A  Downtown Toronto
# 6        M6A        North York
# 7        M6A        North York
# 8        M7A      Queen's Park
# 10       M9A         Etobicoke
# 11       M1B       Scarborough
# 12       M1B       Scarborough
# 14       M3B        North York
# 15       M4B         East York
# 16       M4B         East York
# 17       M5B  Downtown Toronto
# 18       M5B  Downtown Toronto
# 19       M6B        North York
# 22       M9B         Etobicoke
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M1C       Scarborough
# 28       M1C       Scarborough
# 29       M1C       Scarborough
# 31       M3C        North York
# 32       M3C        North York
# 33       M4C         East York
# 34       M5C  Downtown Toronto
# 35       M6C              York
# 38       M9C         Etobicoke
# ..       ...               ...
# 235      M9V         Etobicoke
# 236      M1W       Scarborough
# 239      M4W  Downtown Toronto
# 240      M5W  Downtown Toronto
# 243      M8W         Etobicoke
# 244      M8W         Etobicoke
# 245      M9W         Etobicoke
# 246      M1X       Scarborough
# 249      M4X  Downtown Toronto
# 250      M4X  Downtown Toronto
# 251      M5X  Downtown Toronto
# 252      M5X  Downtown Toronto
# 255      M8X         Etobicoke
# 256      M8X         Etobicoke
# 257      M8X         Etobicoke
# 262      M4Y  Downtown Toronto
# 265      M7Y      East Toronto
# 266      M8Y         Etobicoke
# 267      M8Y         Etobicoke
# 268      M8Y         Etobicoke
# 269      M8Y         Etobicoke
# 270      M8Y         Etobicoke
# 271      M8Y         Etobicoke
# 272      M8Y         Etobicoke
# 273      M8Y         Etobicoke
# 282      M8Z         Etobicoke
# 283      M8Z         Etobicoke
# 284      M8Z         Etobicoke
# 285      M8Z         Etobicoke
# 286      M8Z         Etobicoke
#
#                                          Neighbourhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                                         Harbourfront
# 5                                          Regent Park
# 6                                     Lawrence Heights
# 7                                       Lawrence Manor
# 8                                         Not assigned
# 10                                    Islington Avenue
# 11                                               Rouge
# 12                                             Malvern
# 14                                     Don Mills North
# 15                                    Woodbine Gardens
# 16                                       Parkview Hill
# 17                                             Ryerson
# 18                                     Garden District
# 19                                           Glencairn
# 22                                          Cloverdale
# 23                                           Islington
# 24                                        Martin Grove
# 25                                    Princess Gardens
# 26                                     West Deane Park
# 27                                      Highland Creek
# 28                                          Rouge Hill
# 29                                          Port Union
# 31                                     Flemingdon Park
# 32                                     Don Mills South
# 33                                    Woodbine Heights
# 34                                      St. James Town
# 35                                  Humewood-Cedarvale
# 38                                   Bloordale Gardens
# ..                                                 ...
# 235                                        Thistletown
# 236                                    L'Amoreaux West
# 239                                           Rosedale
# 240                    Stn A PO Boxes 25 The Esplanade
# 243                                          Alderwood
# 244                                        Long Branch
# 245                                          Northwest
# 246                                        Upper Rouge
# 249                                        Cabbagetown
# 250                                     St. James Town
# 251                               First Canadian Place
# 252                                   Underground city
# 255                                       The Kingsway
# 256                                    Montgomery Road
# 257                                     Old Mill North
# 262                               Church and Wellesley
# 265  Business Reply Mail Processing Centre 969 Eastern
# 266                                         Humber Bay
# 267                                   King's Mill Park
# 268                           Kingsway Park South East
# 269                                          Mimico NE
# 270                                     Old Mill South
# 271                                 The Queensway East
# 272                              Royal York South East
# 273                                           Sunnylea
# 282                           Kingsway Park South West
# 283                                          Mimico NW
# 284                                 The Queensway West
# 285                              Royal York South West
# 286                                     South of Bloor
#
# [211 rows x 3 columns]

# %% [markdown]
# More than one neighborhood can exist in one postal code area.  For example, in the table on the Wikipedia page, you will notice that M5A is listed twice and has two neighborhoods: Harbourfront and Regent Park. These two rows will be combined into one row with the neighborhoods separated with a comma as shown in row 11 in the above table.

# %%
df1=df.groupby("Postcode").agg(lambda x:','.join(set(x)))
df1
# Out:
#                    Borough                                      Neighbourhood
# Postcode
# M1B            Scarborough                                      Malvern,Rouge
# M1C            Scarborough               Highland Creek,Rouge Hill,Port Union
# M1E            Scarborough                    Morningside,West Hill,Guildwood
# M1G            Scarborough                                             Woburn
# M1H            Scarborough                                          Cedarbrae
# M1J            Scarborough                                Scarborough Village
# M1K            Scarborough          East Birchmount Park,Kennedy Park,Ionview
# M1L            Scarborough                      Clairlea,Golden Mile,Oakridge
# M1M            Scarborough      Scarborough Village West,Cliffside,Cliffcrest
# M1N            Scarborough                         Birch Cliff,Cliffside West
# M1P            Scarborough  Scarborough Town Centre,Dorset Park,Wexford He...
# M1R            Scarborough                                   Maryvale,Wexford
# M1S            Scarborough                                          Agincourt
# M1T            Scarborough              Sullivan,Clarks Corners,Tam O'Shanter
# M1V            Scarborough  Agincourt North,Milliken,L'Amoreaux East,Steel...
# M1W            Scarborough                                    L'Amoreaux West
# M1X            Scarborough                                        Upper Rouge
# M2H             North York                                  Hillcrest Village
# M2J             North York                         Henry Farm,Oriole,Fairview
# M2K             North York                                    Bayview Village
# M2L             North York                            York Mills,Silver Hills
# M2M             North York                             Willowdale,Newtonbrook
# M2N             North York                                   Willowdale South
# M2P             North York                                    York Mills West
# M2R             North York                                    Willowdale West
# M3A             North York                                          Parkwoods
# M3B             North York                                    Don Mills North
# M3C             North York                    Flemingdon Park,Don Mills South
# M3H             North York      Bathurst Manor,Wilson Heights,Downsview North
# M3J             North York                     York University,Northwood Park
# ...                    ...                                                ...
# M6C                   York                                 Humewood-Cedarvale
# M6E                   York                                Caledonia-Fairbanks
# M6G       Downtown Toronto                                           Christie
# M6H           West Toronto                        Dufferin,Dovercourt Village
# M6J           West Toronto                            Trinity,Little Portugal
# M6K           West Toronto         Parkdale Village,Exhibition Place,Brockton
# M6L             North York                   Upwood Park,North Park,Downsview
# M6M                   York        Mount Dennis,Del Ray,Keelesdale,Silverthorn
# M6N                   York                       The Junction North,Runnymede
# M6P           West Toronto                       The Junction South,High Park
# M6R           West Toronto                              Roncesvalles,Parkdale
# M6S           West Toronto                                  Swansea,Runnymede
# M7A           Queen's Park                                       Not assigned
# M7R            Mississauga              Canada Post Gateway Processing Centre
# M7Y           East Toronto  Business Reply Mail Processing Centre 969 Eastern
# M8V              Etobicoke         New Toronto,Mimico South,Humber Bay Shores
# M8W              Etobicoke                              Alderwood,Long Branch
# M8X              Etobicoke        Montgomery Road,The Kingsway,Old Mill North
# M8Y              Etobicoke  Mimico NE,King's Mill Park,Humber Bay,Royal Yo...
# M8Z              Etobicoke  South of Bloor,Royal York South West,Kingsway ...
# M9A              Etobicoke                                   Islington Avenue
# M9B              Etobicoke  Martin Grove,Islington,Princess Gardens,Clover...
# M9C              Etobicoke  Old Burnhamthorpe,Bloordale Gardens,Eringate,M...
# M9L             North York                                      Humber Summit
# M9M             North York                                    Humberlea,Emery
# M9N                   York                                             Weston
# M9P              Etobicoke                                          Westmount
# M9R              Etobicoke  Richview Gardens,Martin Grove Gardens,St. Phil...
# M9V              Etobicoke  Thistletown,South Steeles,Albion Gardens,Humbe...
# M9W              Etobicoke                                          Northwest
#
# [103 rows x 2 columns]

# %% [markdown]
# If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough. So for the 9th cell in the table on the Wikipedia page, the value of the Borough and the Neighborhood columns will be Queen's Park.

# %%
df1.loc[df1['Neighbourhood']=="Not assigned",'Neighbourhood']=df1.loc[df1['Neighbourhood']=="Not assigned",'Borough']

# %%
df1.reset_index(inplace=True)
df1
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# ..       ...               ...
# 73       M6C              York
# 74       M6E              York
# 75       M6G  Downtown Toronto
# 76       M6H      West Toronto
# 77       M6J      West Toronto
# 78       M6K      West Toronto
# 79       M6L        North York
# 80       M6M              York
# 81       M6N              York
# 82       M6P      West Toronto
# 83       M6R      West Toronto
# 84       M6S      West Toronto
# 85       M7A      Queen's Park
# 86       M7R       Mississauga
# 87       M7Y      East Toronto
# 88       M8V         Etobicoke
# 89       M8W         Etobicoke
# 90       M8X         Etobicoke
# 91       M8Y         Etobicoke
# 92       M8Z         Etobicoke
# 93       M9A         Etobicoke
# 94       M9B         Etobicoke
# 95       M9C         Etobicoke
# 96       M9L        North York
# 97       M9M        North York
# 98       M9N              York
# 99       M9P         Etobicoke
# 100      M9R         Etobicoke
# 101      M9V         Etobicoke
# 102      M9W         Etobicoke
#
#                                          Neighbourhood
# 0                                        Malvern,Rouge
# 1                 Highland Creek,Rouge Hill,Port Union
# 2                      Morningside,West Hill,Guildwood
# 3                                               Woburn
# 4                                            Cedarbrae
# 5                                  Scarborough Village
# 6            East Birchmount Park,Kennedy Park,Ionview
# 7                        Clairlea,Golden Mile,Oakridge
# 8        Scarborough Village West,Cliffside,Cliffcrest
# 9                           Birch Cliff,Cliffside West
# 10   Scarborough Town Centre,Dorset Park,Wexford He...
# 11                                    Maryvale,Wexford
# 12                                           Agincourt
# 13               Sullivan,Clarks Corners,Tam O'Shanter
# 14   Agincourt North,Milliken,L'Amoreaux East,Steel...
# 15                                     L'Amoreaux West
# 16                                         Upper Rouge
# 17                                   Hillcrest Village
# 18                          Henry Farm,Oriole,Fairview
# 19                                     Bayview Village
# 20                             York Mills,Silver Hills
# 21                              Willowdale,Newtonbrook
# 22                                    Willowdale South
# 23                                     York Mills West
# 24                                     Willowdale West
# 25                                           Parkwoods
# 26                                     Don Mills North
# 27                     Flemingdon Park,Don Mills South
# 28       Bathurst Manor,Wilson Heights,Downsview North
# 29                      York University,Northwood Park
# ..                                                 ...
# 73                                  Humewood-Cedarvale
# 74                                 Caledonia-Fairbanks
# 75                                            Christie
# 76                         Dufferin,Dovercourt Village
# 77                             Trinity,Little Portugal
# 78          Parkdale Village,Exhibition Place,Brockton
# 79                    Upwood Park,North Park,Downsview
# 80         Mount Dennis,Del Ray,Keelesdale,Silverthorn
# 81                        The Junction North,Runnymede
# 82                        The Junction South,High Park
# 83                               Roncesvalles,Parkdale
# 84                                   Swansea,Runnymede
# 85                                        Queen's Park
# 86               Canada Post Gateway Processing Centre
# 87   Business Reply Mail Processing Centre 969 Eastern
# 88          New Toronto,Mimico South,Humber Bay Shores
# 89                               Alderwood,Long Branch
# 90         Montgomery Road,The Kingsway,Old Mill North
# 91   Mimico NE,King's Mill Park,Humber Bay,Royal Yo...
# 92   South of Bloor,Royal York South West,Kingsway ...
# 93                                    Islington Avenue
# 94   Martin Grove,Islington,Princess Gardens,Clover...
# 95   Old Burnhamthorpe,Bloordale Gardens,Eringate,M...
# 96                                       Humber Summit
# 97                                     Humberlea,Emery
# 98                                              Weston
# 99                                           Westmount
# 100  Richview Gardens,Martin Grove Gardens,St. Phil...
# 101  Thistletown,South Steeles,Albion Gardens,Humbe...
# 102                                          Northwest
#
# [103 rows x 3 columns]
